# %% [markdown]
# # Face similarity score

# %% [markdown]
# ## Game plan:
# <ol>
#   <li>Take in 2 lists of face-pictures</li>
#   <li>get face locations and encodings</li>
#   <li>cluster faces only</li>
#   <li>get distance between centres of clusters</li>
#   <li>display clusters and similarity score</li>
# </ol>

# %% [markdown]
# ### Importing necessary libraries

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 42kB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.6/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from face_recognition) (1.18.5)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=b0589fdb4ba92a8c7e183086fb3ce35037e134ae782b18352eed93a81c20ef98
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.spatial import distance
import os
import face_recognition
import pickle
from sklearn.cluster import DBSCAN
from imutils import build_montages
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### Setting up google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Getting 2 lists of face-pictures

# %%
face_1 = []
face_2 = []
path_1 = input('Enter the path to folder where one set of pictures are :')
path_2= input('Enter the path to folder where other set of pictures are :')
for filename in os.listdir(path_1):
    if filename.endswith('jpg'):
      face_1.append(path_1+'/'+filename)
for filename in os.listdir(path_2):
    if filename.endswith('jpg'):
      face_2.append(path_2 + '/' + filename)
# Out:
# Enter the path to folder where one set of pictures are :/content/gdrive/My Drive/Data/Maheak
# Enter the path to folder where other set of pictures are :/content/gdrive/My Drive/Data/Vishwang

# %% [markdown]
# ### function to show an image properly

# %%
def show_picture(img):
  img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  fig = plt.figure(figsize=(12,10))
  ax = fig.add_subplot(111)
  ax.imshow(img_rgb)

# %% [markdown]
# ### getting face_locations

# %%
def get_normalized(img):
  yuv_img = cv2.cvtColor(img,cv2.COLOR_RGB2YUV)
  yuv_img[:,:,0] = cv2.equalizeHist(yuv_img[:,:,0])
  final_img = cv2.cvtColor(yuv_img,cv2.COLOR_YUV2RGB)
  norm_image = np.zeros(img.shape)
  norm_img = cv2.normalize(final_img,  norm_image, 0, 255, cv2.NORM_MINMAX)
  return norm_img

# %%
data=[]
model = Xception(weights="imagenet",include_top=False)
#getting encodings for first set of images
for (i,imagePath) in enumerate(face_1):
  print('Processing image {}/{}:'.format(i,len(face_1)))
  print(imagePath)
  img = cv2.imread(imagePath)
  rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  rgb = get_normalized(rgb)
  boxes = face_recognition.face_locations(rgb)
  encodings = face_recognition.face_encodings(rgb, boxes)
  d = [{"imagePath": imagePath, "loc": box, "encoding": enc} 
       for (box, enc) in zip(boxes, encodings)]
       #as there can be multiple faces in an image, 
       #unzipping them all and adding the encodings
  data.extend(d)
#getting encodings for second set of images
for (i,imagePath) in enumerate(face_2):
  print('Processing image {}/{}:'.format((i+1),len(face_2)))
  print(imagePath)
  img = cv2.imread(imagePath)
  rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  rgb = get_normalized(rgb)
  boxes = face_recognition.face_locations(rgb)
  encodings = face_recognition.face_encodings(rgb, boxes)
  d = [{"imagePath": imagePath, "loc": box, "encoding": enc} 
       for (box, enc) in zip(boxes, encodings)]
       #as there can be multiple faces in an image, 
       #unzipping them all and adding the encodings
  data.extend(d)
print(len(data[0]['encoding']))
# Out:
# Processing image 0/42:
# /content/gdrive/My Drive/Data/Maheak/13719667_227089324352203_3102105901639105146_o_2.jpg
# Processing image 1/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20171217_094739.jpg
# Processing image 2/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20171217_100620.jpg
# Processing image 3/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180126_165515.jpg
# Processing image 4/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20180126-WA0030.jpg
# Processing image 5/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20180126-WA0032.jpg
# Processing image 6/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_134402.jpg
# Processing image 7/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_134415.jpg
# Processing image 8/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_134448.jpg
# Processing image 9/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_162651.jpg
# Processing image 10/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_163746.jpg
# Processing image 11/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_192047.jpg
# Processing image 12/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_192051.jpg
# Processing image 13/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_192052.jpg
# Processing image 14/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180127_192053.jpg
# Processing image 15/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180128_184835.jpg
# Processing image 16/42:
# /content/gdrive/My Drive/Data/Maheak/Snapchat-1813150413.jpg
# Processing image 17/42:
# /content/gdrive/My Drive/Data/Maheak/Snapchat-1311519463.jpg
# Processing image 18/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20180128_205848.jpg
# Processing image 19/42:
# /content/gdrive/My Drive/Data/Maheak/Snapchat-285437783.jpg
# Processing image 20/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20180407-WA0020.jpg
# Processing image 21/42:
# /content/gdrive/My Drive/Data/Maheak/Screenshot_20180730-144854.jpg
# Processing image 22/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181027_161515.jpg
# Processing image 23/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181027_161517.jpg
# Processing image 24/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181027_180458.jpg
# Processing image 25/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181028_201429.jpg
# Processing image 26/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181028_201443.jpg
# Processing image 27/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181028_201446.jpg
# Processing image 28/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181110_141603.jpg
# Processing image 29/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181110_141617.jpg
# Processing image 30/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181110_141619.jpg
# Processing image 31/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20181110_141622.jpg
# Processing image 32/42:
# /content/gdrive/My Drive/Data/Maheak/Snapchat-791427351.jpg
# Processing image 33/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20190714_205229.jpg
# Processing image 34/42:
# /content/gdrive/My Drive/Data/Maheak/IMG_20190714_205232.jpg
# Processing image 35/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20190718-WA0035.jpg
# Processing image 36/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20190718-WA0034.jpg
# Processing image 37/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20191202-WA0002.jpg
# Processing image 38/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20191204-WA0005.jpg
# Processing image 39/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20191207-WA0023.jpg
# Processing image 40/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20191222-WA0056.jpg
# Processing image 41/42:
# /content/gdrive/My Drive/Data/Maheak/IMG-20191222-WA0057.jpg
# Processing image 1/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20191223_174807.jpg
# Processing image 2/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20191225_211154.jpg
# Processing image 3/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20191229-WA0002.jpg
# Processing image 4/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200104_083231.jpg
# Processing image 5/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200104_104806.jpg
# Processing image 6/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200108-WA0038.jpg
# Processing image 7/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200111_074507.jpg
# Processing image 8/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200112_123312.jpg
# Processing image 9/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200112_124412.jpg
# Processing image 10/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200119_161306.jpg
# Processing image 11/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200125_125752.jpg
# Processing image 12/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200301-WA0004.jpg
# Processing image 13/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200301_212810.jpg
# Processing image 14/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200308-WA0016.jpg
# Processing image 15/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200311-WA0065.jpg
# Processing image 16/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200313_164813.jpg
# Processing image 17/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200313-WA0002.jpg
# Processing image 18/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200314-WA0007.jpg
# Processing image 19/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200314-WA0008.jpg
# Processing image 20/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200314_154626.jpg
# Processing image 21/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200314_173009.jpg
# Processing image 22/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200315-WA0008.jpg
# Processing image 23/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200315-WA0018.jpg
# Processing image 24/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200315_175247.jpg
# Processing image 25/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200315_175313.jpg
# Processing image 26/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200315_195027.jpg
# Processing image 27/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200315_195049.jpg
# Processing image 28/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200319-WA0008.jpg
# Processing image 29/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200323-WA0011.jpg
# Processing image 30/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200327-WA0007.jpg
# Processing image 31/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200328-WA0011.jpg
# Processing image 32/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200403-WA0024.jpg
# Processing image 33/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200407-WA0043.jpg
# Processing image 34/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200413-WA0010.jpg
# Processing image 35/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200415-WA0002.jpg
# Processing image 36/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200415-WA0004.jpg
# Processing image 37/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200421-WA0018.jpg
# Processing image 38/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200423-WA0018.jpg
# Processing image 39/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200506_055542.jpg
# Processing image 40/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200512-WA0007.jpg
# Processing image 41/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200518-WA0010.jpg
# Processing image 42/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG-20200520-WA0015.jpg
# Processing image 43/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200601_173727.jpg
# Processing image 44/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200603_183548.jpg
# Processing image 45/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200603_183555.jpg
# Processing image 46/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200603_184542.jpg
# Processing image 47/47:
# /content/gdrive/My Drive/Data/Vishwang/IMG_20200603_184555.jpg
# 128

# %%
len(data)
# Out:
# 19

# %%
encodings_path = '/content/gdrive/My Drive'
f = open(encodings_path+'/'+'Face_Data.pickle','wb+')
f.write(pickle.dumps(data))
f.close()

# %% [markdown]
# ### getting data from pickle

# %%
data_path = '/content/gdrive/My Drive/Face_Data.pickle'
data = pickle.loads(open(data_path, "rb").read())
data = np.array(data)

# %% [markdown]
# ### Clustering Faces and showing the clusters

# %%
encodings = [d["encoding"] for d in data]

# %%
print("[INFO] Clustering...")
encodings
clt = DBSCAN(eps=0.38, metric ='euclidean')
clt.fit(encodings)
#finding number of unique faces found
labelIDs = np.unique(clt.labels_)
numUniqueFaces = len(np.where(labelIDs > -1)[0])
print("[INFO] Number of unique faces: {}".format(numUniqueFaces))
# Out:
# [INFO] Clustering...
# [INFO] Number of unique faces: 4

# %%
clustered_faces = []
for labelID in labelIDs:
  print("[INFO] Faces for face ID :{}".format(labelID))
  indexes = np.where(clt.labels_ == labelID)[0]
  faces = []
  for i in indexes:
    image = cv2.imread(data[i]['imagePath'])
    (top,right, bottom,left) = data[i]['loc']
    face = image[top:bottom,left:right]
    #print(type(face))
    encoding = data[i]['encoding']
    d = {'face':face,'encoding':encoding}
    faces.append(d)#contains face+encoding of same cluster
  clustered_faces.append(faces)
# Out:
# [INFO] Faces for face ID :-1
# [INFO] Faces for face ID :0
# [INFO] Faces for face ID :1
# [INFO] Faces for face ID :2
# [INFO] Faces for face ID :3

# %%
for labelID in labelIDs:
  print(f'[INFO] faces for face ID {labelID}')
  idxs = np.where(clt.labels_ == labelID)[0]
  idxs = np.random.choice(idxs,size=min(25,len(idxs)),replace=False)
  faces = []
  for i in idxs:
    image = cv2.imread(data[i]['imagePath'])
    (top,right,bottom,left) = data[i]['loc']
    face = image[top:bottom, left:right]
    face = cv2.resize(face, (96,96))
    faces.append(face)
  montage = build_montages(faces,(96,96),(5,5))[0]
  cv2_imshow(montage)
# Out:
# [INFO] faces for face ID -1
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FF1C86EB3C8>
# [INFO] faces for face ID 0
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FF1C86EB0B8>
# [INFO] faces for face ID 1
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FF1C86EB3C8>
# [INFO] faces for face ID 2
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FF1C86EBF60>
# [INFO] faces for face ID 3
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FF1C86EB0B8>

# %%
clus1 = int(input('Enter the number of the first cluster of images you want to compare :'))
clus2 = int(input('Enter the number of the second cluster of images you want to compare :'))
face_list1 = clustered_faces[clus1+1]
face_list2 = clustered_faces[clus2+1]
show_picture(face_list1[6]['face'])
show_picture(face_list2[0]['face'])
distance_matrix = np.zeros((len(face_list1),len(face_list2)))
for (i,img1) in enumerate(face_list1[:]):
  for (j,img2) in enumerate(face_list2[:]):
    distance_matrix[i][j] = distance.sqeuclidean(img1['encoding'],img2['encoding'])
# Out:
# Enter the number of the first cluster of images you want to compare :0
# Enter the number of the second cluster of images you want to compare :1

# %%
def get_score(distance_matrix):
  mean = np.mean(distance_matrix)
  standardized_mean = (mean - distance_matrix.min())/(distance_matrix.max()-distance_matrix.min())
  return 1/(1+standardized_mean)

# %%
print(get_score(distance_matrix)*100)
# Out:
# 71.0346135199342
